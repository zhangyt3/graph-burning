# %%
import networkx as nx

# %%
g = nx.complete_graph(10)

# %%
nx.draw(g)

# %%
nx.draw(g, pos=nx.spectral_layout(g), node_color='b', edge_color='black')

# %%
min_dom_set = nx.min_weighted_dominating_set(g)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-9d10c646643e> in <module>()
# ----> 1 min_dom_set = nx.min_weighted_dominating_set(g)
#
# AttributeError: module 'networkx' has no attribute 'min_weighted_dominating_set'
